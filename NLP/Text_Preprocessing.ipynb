# %%
pip install nltk

# %%
import re
import string
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
a='http:www.google.com , Hello World , Welcome to NLP Class'

# %%
pattern=re.sub(r'http\S+'," ", a)
re.findall
re.search
# Out:
# <function re.search(pattern, string, flags=0)>

# %%
def remove_url(text):
  return re.sub(r'http\S+'," ", a)

# %%
remove_url(a)
# Out:
# '  , Hello World , Welcome to NLP Class'

# %%
#Remove the Punctuation
exclude=string.punctuation
def remove_punctuation(text):
  return text.translate(str.maketrans('','',exclude))

# %%
remove_punctuation(a)
# Out:
# 'httpwwwgooglecom  Hello World  Welcome to NLP Class'

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stopwords = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Stemming
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

# %%
words=["eating","eats","ate","adjustable","rafting"]
for word in words:
  print(word,"|",stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# ate | ate
# adjustable | adjust
# rafting | raft

# %%
from nltk.stem import WordNetLemmatizer

# %%
'Hello How are You'
# Out:
# 'Hello How are You'

# %%
def lemmatizer(text):
  lemmatizer=WordNetLemmatizer
  words=nltk.word_tokenize(text)
  lemmatizer_words=[lemmatizer.lemmatize(word) for word in words]
  lemmatizer_sentence=" ".join(lemmatizer_words)
  return lemmatizer_sentence

# %%
# !pip install nltk
# !python -m nltk.downloader punkt
# Out:
# ...
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
text="I was playing cricket today","Yogesh was Singing Today","Kishore was reading today"
b=lemmatizer(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8a7dcb72afbe> in <cell line: 2>()
#       1 text="I was playing cricket today","Yogesh was Singing Today","Kishore was reading today"
# ----> 2 b=lemmatizer(text)
#
# <ipython-input-15-74e055c15fc2> in lemmatizer(text)
#       1 def lemmatizer(text):
#       2   lemmatizer=WordNetLemmatizer
# ----> 3   words=nltk.word_tokenize(text)
#       4   lemmatizer_words=[lemmatizer.lemmatize(word) for word in words]
#       5   lemmatizer_sentence=" ".join(lemmatizer_words)
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download the WordNet corpus if you haven't already
nltk.download('wordnet')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to lemmatize text
def lemmatize_text(text):
    lemmatized_text = []
    for sentence in text:
        tokens = word_tokenize(sentence)
        lemmatized_sentence = [lemmatizer.lemmatize(token) for token in tokens]
        lemmatized_text.append(' '.join(lemmatized_sentence))
    return lemmatized_text

# Input text
text = [
    "I  played cricket today",
    "Yogesh  Sang Today",
    "Kishore  reads today"
]

# Lemmatize the text
lemmatized_text = lemmatize_text(text)

# Print the lemmatized text
print(lemmatized_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['I played cricket today', 'Yogesh Sang Today', 'Kishore read today']
